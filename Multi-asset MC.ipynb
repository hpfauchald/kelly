# %%
from kelly_utils import simulate_regime_vol_with_jumps, drawdown, MC_func, simulate_two_asset_returns, rebalanced_returns, stats, kelly_no_shorts, simulate_kelly
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numba import njit

# USER SETTINGS 

periods = 12
n_years = 30

burn_in = 1000

max_leverage = 10.0
min_leverage = 0.0

tc_rate = 0.001

f = 0.75

Rebalancing = 12     # Times per year

scale_long = "none"  # options: "none", "same_avg_vol", "vol_targeting"

sharpe_mode = "constant"  # options: "constant", "variable"

short_constraint = False

annual_ret_eq = 0.05 
annual_ret_b  = 0.02 

SR_eq = 0.40            # Expected annualized sharpe ratio.
SR_b  = 0.40            # Expected annualized sharpe ratio.

m  = 0.00            # degree of momentum

rho_r = 0.90          # correlation in returns

partial_vol = 0.3   # vol_eq / vol_b

# Parameters for volatility simulations

p_LL            = 0.999
p_HH            = 0.99
vol_low_annual  = 0.15
vol_high_annual = 0.40
rho             = 0.95
std_lns         = 0.05
jump_prob       = 0.5/periods
jump_size       = 0.30

# %%
n_sims = 1_000

records = []
for i in range(n_sims):
    metrics = simulate_kelly(
        n_years, periods, burn_in, f, Rebalancing, tc_rate,
        SR_eq, SR_b, partial_vol, m, sharpe_mode,
        short_constraint, annual_ret_eq, annual_ret_b,
        rho_r, p_LL, p_HH,
        vol_low_annual, vol_high_annual,
        rho, std_lns, jump_prob, jump_size, max_leverage
    )
    records.append(metrics)

df = pd.DataFrame(records)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       3 records = []
#       4 for i in range(n_sims):
# ----> 5     metrics = simulate_kelly(
#       6         n_years, periods, burn_in, f, Rebalancing, tc_rate,
#       7         SR_eq, SR_b, partial_vol, m, sharpe_mode,
#       8         short_constraint, annual_ret_eq, annual_ret_b,
#       9         rho_r, p_LL, p_HH,
#      10         vol_low_annual, vol_high_annual,
#      11         rho, std_lns, jump_prob, jump_size, max_leverage
#      12     )
#      13     records.append(metrics)
#      15 df = pd.DataFrame(records)
#
# File c:\Users\carl_\OneDrive\Documents\Skole\Mater thesis\Kode\kelly\kelly_utils.py:589, in simulate_kelly(n_years, periods, burn_in, f, Rebalancing, tc_rate, SR_eq, SR_b, partial_vol, m, sharpe_mode, short_constraint, annual_ret_eq, annual_ret_b, rho_r, p_LL, p_HH, vol_low_annual, vol_high_annual, rho, std_lns, jump_prob, jump_size, max_leverage)
#     586         W[t] = raw
#     588 # 7) Rebalanced log returns & transaction costs for Kelly
# --> 589 net_eq, tc_eq = rebalanced_returns(r_eq, W[:,0]*f, Rebalancing, periods, tc_rate)
#     590 net_b , tc_b  = rebalanced_returns(r_b,  W[:,1]*f, Rebalancing, periods, tc_rate)
#     592 Kelly_r = net_eq + net_b
#
# File c:\Users\carl_\OneDrive\Documents\Skole\Mater thesis\Kode\kelly\kelly_utils.py:341, in rebalanced_returns(R, w, rebalancing, periods, tc)
#     338 n = len(rebalance_points)
#     340 Rp = np.zeros(n)
# --> 341 trade_costs = np.zeros(n)
#     343 for idx, i in enumerate(rebalance_points):
#     344     # cumulative return over the last interval
#     345     prev_ret = R[i - step : i].sum()
#
# KeyboardInterrupt:

# %%
print(df.describe())
# Out:
#        Kelly_sharpe   Kelly_FinalW  Kelly_maxDD  tc_eq_Kelly   tc_b_Kelly  \
# count   1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean       0.561486    1191.517190    -0.730567     0.052184     0.070410
# std        0.175168   14298.851205     0.113836     0.007919     0.030741
# min       -0.067176       0.054225    -0.986134     0.043269     0.046400
# 25%        0.448220      19.775581    -0.809982     0.048843     0.056228
# 50%        0.559773      75.967625    -0.732461     0.050733     0.061345
# 75%        0.674302     306.725967    -0.646241     0.053012     0.071851
# max        1.114053  438089.042996    -0.417812     0.158986     0.415769
#
#          EW_sharpe    EW_FinalW     EW_maxDD     tc_eq_EW      tc_b_EW
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.452836    13.446622    -0.413951     0.004606     0.001383
# std       0.179158    56.972058     0.142212     0.001340     0.000391
# min      -0.160807     0.106798    -0.955548     0.002988     0.000874
# 25%       0.334452     2.929133    -0.494255     0.003789     0.001136
# 50%       0.449971     5.011093    -0.382550     0.004195     0.001265
# 75%       0.564502     9.514112    -0.305679     0.004961     0.001493
# max       1.004536  1429.519665    -0.157077     0.015092     0.003545
